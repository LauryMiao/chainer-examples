# %%
import chainer
import chainer.links as L
import chainer.functions as F
from chainer import iterators, datasets, optimizers
from chainer.dataset import concat_examples
import numpy as np
import math

# %%
# Parameters
learning_rate = 0.01
training_epochs = 100
batch_size = 128
display_step = 1

# Network Parameters
channels = [1, 32, 64] # 2nd layer number of neurons
k_size = 5
stride = 1
pad = 1
pool_size = 2
pool_stride = 2
n_hiddens_1 = 1024
num_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# %%
# Load data
train, test = chainer.datasets.get_mnist(withlabel=True, ndim=3, scale=1.)
reduced_train = chainer.iterators.SerialIterator(dataset=train, batch_size=5000, repeat=True, shuffle=True).next()
reduced_test = chainer.iterators.SerialIterator(dataset=train, batch_size=1000, repeat=True, shuffle=True).next()
train_iter = chainer.iterators.SerialIterator(dataset=reduced_train, batch_size=batch_size, 
                                              repeat=True, shuffle=True)
test_iter = chainer.iterators.SerialIterator(dataset=reduced_test, batch_size=batch_size, 
                                             repeat=False, shuffle=False)

# %% [markdown]
# ### Convolutional layer
# Input: (batch_size, channels, height, width)

# %%
class CNN(chainer.Chain):
    def __init__(self):
        super(CNN, self).__init__()
        with self.init_scope():
            self.conv1 = L.Convolution2D(in_channels=channels[0], 
                                         out_channels=channels[1], 
                                         ksize=k_size, 
                                         stride=stride, pad=pad)
            self.conv2 = L.Convolution2D(in_channels=channels[1], 
                                         out_channels=channels[2], 
                                         ksize=k_size, 
                                         stride=stride, pad=pad)
            self.fc1 = L.Linear(in_size=None, out_size=n_hiddens_1)
            self.fc2 = L.Linear(in_size=n_hiddens_1, out_size=num_classes)
            
    def __call__(self, x, training=False):
        z1 = F.relu(self.conv1(x))
        max_z1 = F.max_pooling_2d(z1, ksize=pool_size, stride=pool_stride)
        z2 = F.relu(self.conv2(max_z1))
        max_z2 = F.max_pooling_2d(z2, ksize=pool_size, stride=pool_stride)
        z3 = F.relu(self.fc1(max_z2))
        h = self.fc2(z3)
        if chainer.config.train:
            h = F.dropout(h, dropout)
        return h

# %%
model = CNN()
optimiser = chainer.optimizers.SGD(lr=learning_rate)
optimiser.setup(model)

# %%
def reset_iter_state(iterator):
    iterator.epoch = 0
    iterator.current_position = 0
    iterator.is_new_epoch = False
    iterator._pushed_position = None

# %%
reset_iter_state(train_iter)

while train_iter.epoch < training_epochs:
    train_batch = train_iter.next()
    image_train, target_train = concat_examples(train_batch)
    
    # Calculate the prediction of the network
    prediction_train = model(image_train)

    # Calculate the loss with softmax_cross_entropy
    loss = F.softmax_cross_entropy(prediction_train, target_train)

    # Calculate the gradients in the network
    model.cleargrads()
    loss.backward()
    
    # Update all the trainable paremters
    optimiser.update()
    # --------------------- until here ---------------------

    # Check the validation accuracy of prediction after every epoch
    if train_iter.is_new_epoch and (train_iter.epoch + 1) % display_step == 0:
        # If this iteration is the final iteration of the current epoch
        with chainer.using_config('train', False):
            test_losses = []
            test_accuracies = []
            while True:
                test_batch = test_iter.next()
                image_test, target_test = concat_examples(test_batch)

                # Forward the test data
                prediction_test = model(image_test)

                # Calculate the loss
                loss_test = F.softmax_cross_entropy(prediction_test, target_test)
                test_losses.append(loss_test.data)

                # Calculate the accuracy
                accuracy = F.accuracy(prediction_test, target_test)
                test_accuracies.append(accuracy.data)

                if test_iter.is_new_epoch:
                    reset_iter_state(test_iter)
                    break

            print('epoch={:03d} train_loss={:.05f} val_loss={:.05f} val_accuracy={:.05f}'.format(
                train_iter.epoch + 1, float(loss.data), np.mean(test_losses), np.mean(test_accuracies)))
# Out:
# epoch=002 train_loss=2.02196 val_loss=1.89633 val_accuracy=0.71387
# epoch=003 train_loss=1.90810 val_loss=1.61309 val_accuracy=0.76660
# epoch=004 train_loss=1.73206 val_loss=1.41903 val_accuracy=0.86426
# epoch=005 train_loss=1.73137 val_loss=1.27605 val_accuracy=0.88379
# epoch=006 train_loss=1.78970 val_loss=1.18834 val_accuracy=0.89941
# epoch=007 train_loss=1.77280 val_loss=1.12085 val_accuracy=0.91406
# epoch=008 train_loss=1.76641 val_loss=1.04981 val_accuracy=0.91602
# epoch=009 train_loss=1.63876 val_loss=0.99821 val_accuracy=0.90234
# epoch=010 train_loss=1.54371 val_loss=0.95356 val_accuracy=0.91797
# epoch=011 train_loss=1.67924 val_loss=0.91687 val_accuracy=0.92285
# epoch=012 train_loss=1.58991 val_loss=0.87299 val_accuracy=0.92676
# epoch=013 train_loss=1.65448 val_loss=0.86471 val_accuracy=0.91992
# epoch=014 train_loss=1.60676 val_loss=0.82400 val_accuracy=0.93457
# epoch=015 train_loss=1.60100 val_loss=0.81788 val_accuracy=0.92969
# epoch=016 train_loss=1.46830 val_loss=0.77951 val_accuracy=0.94141
# epoch=017 train_loss=1.80873 val_loss=0.77082 val_accuracy=0.93555
# epoch=018 train_loss=1.70323 val_loss=0.76866 val_accuracy=0.91797
# epoch=019 train_loss=1.63668 val_loss=0.72652 val_accuracy=0.94336
# epoch=020 train_loss=1.71269 val_loss=0.70436 val_accuracy=0.94141
# epoch=021 train_loss=1.61955 val_loss=0.70291 val_accuracy=0.94336
# epoch=022 train_loss=1.53921 val_loss=0.68401 val_accuracy=0.94434
# epoch=023 train_loss=1.69431 val_loss=0.65997 val_accuracy=0.94824
# epoch=024 train_loss=1.46869 val_loss=0.66758 val_accuracy=0.93652
# epoch=025 train_loss=1.72435 val_loss=0.64882 val_accuracy=0.94336
# epoch=026 train_loss=1.61456 val_loss=0.63676 val_accuracy=0.94531
# epoch=027 train_loss=1.50322 val_loss=0.62379 val_accuracy=0.94922
# epoch=028 train_loss=1.41603 val_loss=0.60974 val_accuracy=0.95020
# epoch=029 train_loss=1.68656 val_loss=0.60135 val_accuracy=0.95215
# epoch=030 train_loss=1.59624 val_loss=0.60297 val_accuracy=0.94727
# epoch=031 train_loss=1.65315 val_loss=0.57982 val_accuracy=0.95020
# epoch=032 train_loss=1.58289 val_loss=0.56313 val_accuracy=0.94629
# epoch=033 train_loss=1.64931 val_loss=0.55678 val_accuracy=0.94824
# epoch=034 train_loss=1.45939 val_loss=0.56326 val_accuracy=0.93457
# epoch=035 train_loss=1.41796 val_loss=0.53722 val_accuracy=0.95020
# epoch=036 train_loss=1.57705 val_loss=0.52991 val_accuracy=0.95312
# epoch=037 train_loss=1.53642 val_loss=0.51469 val_accuracy=0.95117
# epoch=038 train_loss=1.57432 val_loss=0.51857 val_accuracy=0.95703
# epoch=039 train_loss=1.52503 val_loss=0.50996 val_accuracy=0.95898
# epoch=040 train_loss=1.56012 val_loss=0.50939 val_accuracy=0.95312
# epoch=041 train_loss=1.45401 val_loss=0.48755 val_accuracy=0.95898
# epoch=042 train_loss=1.63390 val_loss=0.47754 val_accuracy=0.95605
# epoch=043 train_loss=1.60745 val_loss=0.47839 val_accuracy=0.96094
# epoch=044 train_loss=1.72369 val_loss=0.47859 val_accuracy=0.95996
# epoch=045 train_loss=1.57306 val_loss=0.47288 val_accuracy=0.95215
# epoch=046 train_loss=1.49468 val_loss=0.45916 val_accuracy=0.95898
# epoch=047 train_loss=1.78712 val_loss=0.44942 val_accuracy=0.95996
# epoch=048 train_loss=1.52624 val_loss=0.45054 val_accuracy=0.95312
# epoch=049 train_loss=1.57164 val_loss=0.45687 val_accuracy=0.95996
# epoch=050 train_loss=1.48054 val_loss=0.45073 val_accuracy=0.95703
# epoch=051 train_loss=1.53401 val_loss=0.43842 val_accuracy=0.95996
# epoch=052 train_loss=1.34240 val_loss=0.44288 val_accuracy=0.95312
# epoch=053 train_loss=1.64659 val_loss=0.42281 val_accuracy=0.95605
# epoch=054 train_loss=1.58671 val_loss=0.41310 val_accuracy=0.96191
# epoch=055 train_loss=1.46764 val_loss=0.41580 val_accuracy=0.96289
# epoch=056 train_loss=1.62206 val_loss=0.40556 val_accuracy=0.95996
# epoch=057 train_loss=1.60849 val_loss=0.40080 val_accuracy=0.96387
# epoch=058 train_loss=1.55764 val_loss=0.39394 val_accuracy=0.96289
# epoch=059 train_loss=1.64422 val_loss=0.40037 val_accuracy=0.95605
# epoch=060 train_loss=1.53979 val_loss=0.39996 val_accuracy=0.96387
# epoch=061 train_loss=1.51975 val_loss=0.38685 val_accuracy=0.95996
# epoch=062 train_loss=1.61554 val_loss=0.39715 val_accuracy=0.95312
# epoch=063 train_loss=1.63830 val_loss=0.37757 val_accuracy=0.96094
# epoch=064 train_loss=1.55999 val_loss=0.37764 val_accuracy=0.95703
# epoch=065 train_loss=1.47463 val_loss=0.37577 val_accuracy=0.96387
# epoch=066 train_loss=1.64200 val_loss=0.37041 val_accuracy=0.95898
# epoch=067 train_loss=1.66275 val_loss=0.36549 val_accuracy=0.96289
# epoch=068 train_loss=1.51173 val_loss=0.35032 val_accuracy=0.96484
# epoch=069 train_loss=1.53589 val_loss=0.36597 val_accuracy=0.96484
# epoch=070 train_loss=1.62176 val_loss=0.35396 val_accuracy=0.96191
# epoch=071 train_loss=1.51442 val_loss=0.36218 val_accuracy=0.96289
# epoch=072 train_loss=1.68760 val_loss=0.35913 val_accuracy=0.95898
# epoch=073 train_loss=1.49339 val_loss=0.35269 val_accuracy=0.96680
# epoch=074 train_loss=1.73602 val_loss=0.34140 val_accuracy=0.96680
# epoch=075 train_loss=1.65039 val_loss=0.34651 val_accuracy=0.95996
# epoch=076 train_loss=1.52790 val_loss=0.33662 val_accuracy=0.96289
# epoch=077 train_loss=1.53919 val_loss=0.33882 val_accuracy=0.95508
# epoch=078 train_loss=1.51712 val_loss=0.33425 val_accuracy=0.96289
# epoch=079 train_loss=1.54645 val_loss=0.32814 val_accuracy=0.96484
# epoch=080 train_loss=1.52860 val_loss=0.32935 val_accuracy=0.96484
# epoch=081 train_loss=1.68515 val_loss=0.31959 val_accuracy=0.96875
# epoch=082 train_loss=1.47628 val_loss=0.31371 val_accuracy=0.96387
# epoch=083 train_loss=1.66995 val_loss=0.31028 val_accuracy=0.96484
# epoch=084 train_loss=1.54050 val_loss=0.31990 val_accuracy=0.95801
# epoch=085 train_loss=1.54065 val_loss=0.31434 val_accuracy=0.95898
# epoch=086 train_loss=1.64797 val_loss=0.30795 val_accuracy=0.96094
# epoch=087 train_loss=1.71417 val_loss=0.30782 val_accuracy=0.96387
# epoch=088 train_loss=1.58935 val_loss=0.30891 val_accuracy=0.96680
# epoch=089 train_loss=1.52968 val_loss=0.30251 val_accuracy=0.96484
# epoch=090 train_loss=1.56795 val_loss=0.30031 val_accuracy=0.96289
# epoch=091 train_loss=1.48843 val_loss=0.30959 val_accuracy=0.96680
# epoch=092 train_loss=1.45983 val_loss=0.29701 val_accuracy=0.96582
# epoch=093 train_loss=1.46861 val_loss=0.28813 val_accuracy=0.96777
# epoch=094 train_loss=1.52785 val_loss=0.29603 val_accuracy=0.96289
# epoch=095 train_loss=1.49601 val_loss=0.28556 val_accuracy=0.96680
# epoch=096 train_loss=1.43174 val_loss=0.28828 val_accuracy=0.96484
# epoch=097 train_loss=1.68383 val_loss=0.28043 val_accuracy=0.96777
# epoch=098 train_loss=1.41217 val_loss=0.27906 val_accuracy=0.96875
# epoch=099 train_loss=1.59704 val_loss=0.27013 val_accuracy=0.97070
# epoch=100 train_loss=1.31329 val_loss=0.28371 val_accuracy=0.95996
# epoch=101 train_loss=1.50392 val_loss=0.26321 val_accuracy=0.97070
